# %%
import os
import pandas as pd

# %%
# Set the folder where all monthly CPI files are stored
folder_path = "path"  # update this path to your folder

# %%
# Container for cleaned data
all_months = []

# %%
# Loop through each Excel file in the folder
for file in sorted(os.listdir(folder_path)):
    if file.lower().endswith((".xls", ".xlsx")):
        print(f"Processing file: {file}")
        try:
            # Extract month and year
            base_name = file.replace(".xlsx", "")
            month_str, year_str = base_name.split("_")
            file_date = pd.to_datetime(f"{year_str}-{month_str}")

            file_path = os.path.join(folder_path, file)
            df = pd.read_excel(file_path, skiprows=6)

            df = df.rename(columns={
                df.columns[1]: "SubGroup_Code",
                df.columns[2]: "Description",
                df.columns[9]: "Weight", 
                df.columns[11]: "Provisional_CPI"
            })

            # Drop non-subgroup rows
            df = df[~df["SubGroup_Code"].isna() & ~df["Description"].isna()]
            df = df[pd.to_numeric(df["Provisional_CPI"], errors="coerce").notna()]

            df_clean = df[["SubGroup_Code", "Description", "Weight", "Provisional_CPI"]].copy()
            df_clean["Date"] = pd.to_datetime(file_date.strftime('%Y-%m-%d'), format='%Y-%m-%d')
            df_clean = df_clean.rename(columns={"Provisional_CPI": "CPI"})

            all_months.append(df_clean)
            print(f"Successfully processed {file}")

        except Exception as e:
            print(f"Error processing {file}: {e}")
# Out:
# Processing file: 01_2017.xlsx
# Successfully processed 01_2017.xlsx
# Processing file: 01_2018.xlsx
# Successfully processed 01_2018.xlsx
# Processing file: 01_2019.xlsx
# Successfully processed 01_2019.xlsx
# Processing file: 01_2020.xlsx
# Successfully processed 01_2020.xlsx
# Processing file: 01_2021.xlsx
# Successfully processed 01_2021.xlsx
# Processing file: 01_2022.xlsx
# Successfully processed 01_2022.xlsx
# Processing file: 01_2023.xlsx
# Successfully processed 01_2023.xlsx
# Processing file: 01_2024.xlsx
# Successfully processed 01_2024.xlsx
# Processing file: 01_2025.xlsx
# Successfully processed 01_2025.xlsx
# Processing file: 02_2017.xlsx
# Successfully processed 02_2017.xlsx
# Processing file: 02_2018.xlsx
# Successfully processed 02_2018.xlsx
# Processing file: 02_2019.xlsx
# Successfully processed 02_2019.xlsx
# Processing file: 02_2020.xlsx
# Successfully processed 02_2020.xlsx
# Processing file: 02_2021.xlsx
# Successfully processed 02_2021.xlsx
# Processing file: 02_2022.xlsx
# Successfully processed 02_2022.xlsx
# Processing file: 02_2023.xlsx
# Successfully processed 02_2023.xlsx
# Processing file: 02_2024.xlsx
# Successfully processed 02_2024.xlsx
# Processing file: 02_2025.xlsx
# Successfully processed 02_2025.xlsx
# Processing file: 03_2017.xlsx
# Successfully processed 03_2017.xlsx
# Processing file: 03_2018.xlsx
# Successfully processed 03_2018.xlsx
# Processing file: 03_2019.xlsx
# Successfully processed 03_2019.xlsx
# Processing file: 03_2020.xlsx
# Successfully processed 03_2020.xlsx
# Processing file: 03_2021.xlsx
# Successfully processed 03_2021.xlsx
# Processing file: 08_2022.xlsx
# Successfully processed 08_2022.xlsx
# Processing file: 08_2023.xlsx
# Successfully processed 08_2023.xlsx
# Processing file: 08_2024.xlsx
# Successfully processed 08_2024.xlsx
# Processing file: 09_2016.xlsx
# Successfully processed 09_2016.xlsx
# Processing file: 09_2017.xlsx
# Successfully processed 09_2017.xlsx
# Processing file: 09_2019.xlsx
# Successfully processed 09_2019.xlsx
# Processing file: 09_2020.xlsx
# Successfully processed 09_2020.xlsx
# Processing file: 09_2021.xlsx
# Successfully processed 09_2021.xlsx
# Processing file: 09_2022.xlsx
# Successfully processed 09_2022.xlsx
# Processing file: 09_2023.xlsx
# Successfully processed 09_2023.xlsx
# Processing file: 09_2024.xlsx
# Successfully processed 09_2024.xlsx
# Processing file: 10_2016.xlsx
# Successfully processed 10_2016.xlsx
# Processing file: 10_2017.xlsx
# Successfully processed 10_2017.xlsx
# Processing file: 10_2018.xlsx
# Successfully processed 10_2018.xlsx
# Processing file: 10_2019.xlsx
# Successfully processed 10_2019.xlsx
# Processing file: 10_2021.xlsx
# Successfully processed 10_2021.xlsx
# Processing file: 10_2022.xlsx
# Successfully processed 10_2022.xlsx
# Processing file: 10_2023.xlsx
# Successfully processed 10_2023.xlsx
# Processing file: 10_2024.xlsx
# Successfully processed 10_2024.xlsx
# Processing file: 11_2016.xlsx
# Successfully processed 11_2016.xlsx
# Processing file: 11_2017.xlsx
# Successfully processed 11_2017.xlsx
# Processing file: 11_2018.xlsx
# Successfully processed 11_2018.xlsx
# Processing file: 11_2019.xlsx
# Successfully processed 11_2019.xlsx
# Processing file: 11_2020.xlsx
# Successfully processed 11_2020.xlsx
# Processing file: 11_2021.xlsx
# Successfully processed 11_2021.xlsx
# Processing file: 11_2022.xlsx
# Successfully processed 11_2022.xlsx
# Processing file: 11_2023.xlsx
# Successfully processed 11_2023.xlsx
# Processing file: 11_2024.xlsx
# Successfully processed 11_2024.xlsx
# Processing file: 12_2016.xlsx
# Successfully processed 12_2016.xlsx
# Processing file: 12_2017.xlsx
# Successfully processed 12_2017.xlsx
# Processing file: 12_2018.xlsx
# Successfully processed 12_2018.xlsx
# Processing file: 12_2019.xlsx
# Successfully processed 12_2019.xlsx
# Processing file: 12_2020.xlsx
# Successfully processed 12_2020.xlsx
# Processing file: 12_2021.xlsx
# Successfully processed 12_2021.xlsx
# Processing file: 12_2022.xlsx
# Successfully processed 12_2022.xlsx
# Processing file: 12_2023.xlsx
# Successfully processed 12_2023.xlsx
# Processing file: 12_2024.xlsx
# Successfully processed 12_2024.xlsx

# %%
# Concatenate all monthly data
final_df = pd.concat(all_months, ignore_index=True)

# Sort by date and subgroup
final_df = final_df.sort_values(by=["SubGroup_Code", "Date"])

# %%
# Output to CSV
final_df.to_csv("F:/ML/CPI/Weighted_CPI_Forecasting/combined_cpi_data.csv", index=False)
